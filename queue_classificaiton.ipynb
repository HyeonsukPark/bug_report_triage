# %% [markdown]
# # Download libraries

# %%
# download

# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 115.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
# download the NLTK data
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')

# Load the spaCy model for Lemmatization
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
# !pip install tensorflow==2.18.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.4/615.4 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 50.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.3
#     Uninstalling ml_dtypes-0.5.3:
#       Successfully uninstalled ml_dtypes-0.5.3
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.19.0
#     Uninstalling tensorboard-2.19.0:
#       Successfully uninstalled tensorboard-2.19.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.19.0
#     Uninstalling tensorflow-2.19.0:
#       Successfully uninstalled tensorflow-2.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install transformers==4.48.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 55.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.54.1
#     Uninstalling transformers-4.54.1:
#       Successfully uninstalled transformers-4.54.1
# ...

# %%
# !pip install --upgrade tiktoken -q

# %%
# !pip uninstall openai

# %%
# !pip install openai

# %%
# !pip install python-dotenv

# %%
# !pip install joblib

# %%
# !pip install gensim
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 76.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 108.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 60.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %% [markdown]
# # Load libaries

# %%
## Allow Colab to see Google Drive files

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#basic imports
import warnings
warnings.filterwarnings('ignore')
from time import time
from tqdm import tqdm
import pickle
import joblib
from joblib import Parallel, delayed

import csv
import pandas as pd
import numpy as np
import re
import string
import seaborn as sns
import matplotlib.pyplot as plt
import spacy

# NLTK
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords

# For ModernBERT
from transformers import BertTokenizer, AutoTokenizer, AutoModel, BertModel, TFBertModel
from sentence_transformers import SentenceTransformer
import torch

# For GPT
import openai

# Gemini
import google.generativeai as genai

# For train-test split, grid search and evaluation
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.preprocessing import LabelEncoder

# %%
from gensim import corpora
from gensim.models import LdaModel

# %%
# For handling imbalanced data
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from imblearn import FunctionSampler
from collections import Counter

# %%
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
! python --version
# Out:
# Python 3.11.13

# %% [markdown]
# # Generating requirements.txt file

# %%
# from google.colab import files
# uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc05fc7e-8e9e-47da-a387-3ee70ccc3c90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc05fc7e-8e9e-47da-a387-3ee70ccc3c90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# pip freeze > requirements.txt

# %%
# from google.colab import files
# files.download('requirements.txt')

# %% [markdown]
# # Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Project/customer_ticket/dataset/ticket_dataset_1.csv')
df.head(5)
# Out:
#                                              subject  \
# 0                    Wesentlicher Sicherheitsvorfall
# 1                                 Account Disruption
# 2  Query About Smart Home System Integration Feat...
# 3                  Inquiry Regarding Invoice Details
# 4  Question About Marketing Agency Software Compa...
#
#                                                 body  \
# 0  Sehr geehrtes Support-Team,\n\nich möchte eine...
# 1  Dear Customer Support Team,\n\nI am writing to...
# 2  Dear Customer Support Team,\n\nI hope this mes...
# 3  Dear Customer Support Team,\n\nI hope this mes...
# 4  Dear Support Team,\n\nI hope this message reac...
#
#                                               answer      type  \
# 0  Vielen Dank für die Meldung des kritischen Sic...  Incident
# 1  Thank you for reaching out, <name>. We are awa...  Incident
# 2  Thank you for your inquiry. Our products suppo...   Request
# 3  We appreciate you reaching out with your billi...   Request
# ...

# %%
# language filtering - since the dataset includes emails in english and german, we will filter the dataset to have data only in english

df = df[df['language'] == 'en']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16338 entries, 1 to 28586
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subject   13731 non-null  object
#  1   body      16338 non-null  object
#  2   answer    16335 non-null  object
#  3   type      16338 non-null  object
#  4   queue     16338 non-null  object
#  5   priority  16338 non-null  object
#  6   language  16338 non-null  object
#  7   version   16338 non-null  int64
#  8   tag_1     16338 non-null  object
#  9   tag_2     16332 non-null  object
#  10  tag_3     16269 non-null  object
#  11  tag_4     14627 non-null  object
#  12  tag_5     8416 non-null   object
#  13  tag_6     3370 non-null   object
#  14  tag_7     1134 non-null   object
#  15  tag_8     281 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 2.1+ MB

# %%
# the type of ticket as picked by the agent

df['type'].value_counts()
# Out:
# type
# Incident    6571
# Request     4665
# Problem     3397
# Change      1705
# Name: count, dtype: int64

# %%
# department to which the email ticket is routed

df['queue'].value_counts()
# Out:
# queue
# Technical Support                  4737
# Product Support                    3073
# Customer Service                   2410
# IT Support                         1942
# Billing and Payments               1595
# Returns and Exchanges               820
# Service Outages and Maintenance     664
# Sales and Pre-Sales                 513
# Human Resources                     348
# General Inquiry                     236
# Name: count, dtype: int64

# %%
# indicates the urgency and importance of the issue

df['priority'].value_counts()
# Out:
# priority
# medium    6618
# high      6346
# low       3374
# Name: count, dtype: int64

# %% [markdown]
# # Data Filtering

# %% [markdown]
# We intends to classify the type of queues to decide a department to which the email ticket is routed. To focus on the important and busy department, we will do filtering - to keep Technical Support, Product Support, Customer Service, IT Support, Billing and Payments, and Returns and Exchanges.

# %%
# Filter the dataframe to keep the relevant queues
relevant_queues = ['Technical Support', 'Product Support', 'Customer Service', 'IT Support', 'Billing and Payments']
df = df[df['queue'].isin(relevant_queues)]

# %%
# check the number of queues

df['queue'].value_counts()
# Out:
# queue
# Technical Support       4737
# Product Support         3073
# Customer Service        2410
# IT Support              1942
# Billing and Payments    1595
# Name: count, dtype: int64

# %%
# filtering columns
corpus = df[['subject', 'body', 'queue']]
corpus.head(5)
# Out:
#                                               subject  \
# 1                                  Account Disruption
# 3                   Inquiry Regarding Invoice Details
# 5                                       Feature Query
# 7   Connectivity Problems with Printer on MacBook Pro
# 10                                   VPN Access Issue
#
#                                                  body                 queue
# 1   Dear Customer Support Team,\n\nI am writing to...     Technical Support
# 3   Dear Customer Support Team,\n\nI hope this mes...  Billing and Payments
# 5   Dear Customer Support,\n\nI hope this message ...     Technical Support
# 7   Dear Support Team,\n\nI am reporting a recurri...     Technical Support
# 10  Customer Support,\n\nWe are encountering a dis...       Product Support

# %%
# duplicated data
duplicated_data = corpus.duplicated().sum()
print(f"Number of duplicated data: {duplicated_data}")
# Out:
# Number of duplicated data: 0

# %% [markdown]
# We will combine subject and body to create a new column 'email_content'

# %%
# Fill NaN values in 'subject' and 'body' columns

corpus['subject'] = corpus['subject'].fillna("")
corpus['body'] = corpus['body'].fillna("")

# %%
# Combine 'summary' and 'description' into a single text column
corpus['email_content'] = corpus['subject'] + " " + corpus['body']

# %%
df = corpus[['email_content', 'queue']]
df.head(5)
# Out:
#                                         email_content                 queue
# 1   Account Disruption Dear Customer Support Team,...     Technical Support
# 3   Inquiry Regarding Invoice Details Dear Custome...  Billing and Payments
# 5   Feature Query Dear Customer Support,\n\nI hope...     Technical Support
# 7   Connectivity Problems with Printer on MacBook ...     Technical Support
# 10  VPN Access Issue Customer Support,\n\nWe are e...       Product Support

# %%
display(df.shape)
# Out:
# (13757, 2)

# %% [markdown]
# # Data Pre-processing

# %%
# function to do text pre-processing

def text_cleaning(text):

    text = str(text).lower()

    # Remove text inside square brackets
    text = re.sub(r'\[.*?\]', '', text)

    # Remove URLs
    text = re.sub(r'http\S+|www\S+', '', text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove words containing numbers (using word boundaries)
    text = re.sub(r'\b\w*\d\w*\b', '', text)

    # Remove any remaining non-alphabetic characters
    text = re.sub(r'[^a-z\s]', '', text)

    # Remove extra whitespace (spaces, line breaks)
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
def bug_processing(series):

    stop_words = set(stopwords.words('english'))

    # Apply text cleaning to the entire series
    cleaned_series = series.apply(text_cleaning)

    # Tokenize and remove stopwords using a concise lambda function
    processed_series = cleaned_series.apply(
        lambda text: ' '.join([token for token in word_tokenize(text) if token not in stop_words])
    )

    return processed_series

# %%
# Apply text cleaning
df['email_content_clean'] = bug_processing(df['email_content'])

# %% [markdown]
# ## Encoding target classes

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
label_map = {
    "Technical Support": 0,
    "Product Support": 1,
    "Customer Service": 2,
    "IT Support": 3,
    "Billing and Payments": 4,
}

# %%
df['queue_label'] = df['queue'].map(label_map)

# %%
df = df[['email_content_clean', 'queue', 'queue_label']]
df.head(5)
# Out:
#                                   email_content_clean                 queue  \
# 1   account disruption dear customer support teamn...     Technical Support
# 3   inquiry regarding invoice details dear custome...  Billing and Payments
# 5   feature query dear customer supportnni hope me...     Technical Support
# 7   connectivity problems printer macbook pro dear...     Technical Support
# 10  vpn access issue customer supportnnwe encounte...       Product Support
#
#     queue_label
# 1             0
# 3             4
# 5             0
# 7             0
# 10            1

# %%
df['queue_label'].value_counts()
# Out:
# queue_label
# 0    4737
# 1    3073
# 2    2410
# 3    1942
# 4    1595
# Name: count, dtype: int64

# %% [markdown]
# ## Save the cleaned dataset

# %%
df.to_csv('/content/drive/MyDrive/ML Project/customer_ticket/dataset/cleaned_dataset_queue.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/ML Project/customer_ticket/dataset/cleaned_dataset_queue.csv')

# %% [markdown]
# # LDA

# %%
# create a dictionary and corpus
dictionary = corpora.Dictionary(df['email_content_clean'].apply(word_tokenize))
corpus = [dictionary.doc2bow(word_tokenize(text)) for text in df['email_content_clean']]

# %%
# Run LDA model
num_topics = 5
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %%
# get topic distribution for each document
def get_topic_distribution(lda_model, corpus, num_topics):
    topic_distributions = []
    for doc in corpus:
        # get the topic probabilities for each document
        doc_topics = lda_model.get_document_topics(doc, minimum_probability=0)
        # Extract just the probability values in the correct order
        topic_distributions.append([prob for _, prob in doc_topics])
    # Convert the list of lists to a NumPy array
    return np.array(topic_distributions)

# Get the topic distributions to use as features
topic_features = get_topic_distribution(lda_model, corpus, num_topics)

# %%
lda_df = pd.DataFrame(topic_features, columns=[f'topic_{i}' for i in range(num_topics)])
df = pd.concat([df, lda_df], axis=1)

# %%
df
# Out:
#                                      email_content_clean  \
# 0      account disruption dear customer support teamn...
# 1      inquiry regarding invoice details dear custome...
# 2      feature query dear customer supportnni hope me...
# 3      connectivity problems printer macbook pro dear...
# 4      vpn access issue customer supportnnwe encounte...
# ...                                                  ...
# 13752  problem billing adjustment unexpected billing ...
# 13753  urgent incident involving data breach medical ...
# 13754  performance problem data analytics tool data a...
# 13755  update request saas platform integration featu...
# 13756  inquiry project management features looking de...
#
#                       queue  queue_label   topic_0   topic_1   topic_2  \
# 0         Technical Support            0  0.223657  0.083583  0.316111
# 1      Billing and Payments            4  0.003570  0.003540  0.003520
# ...

# %%
num_top_words = 10
for topic_id, topic in lda_model.show_topics(num_topics=5, num_words=num_top_words, formatted=False):
    print(f"Topic {topic_id}: {[word for word, prob in topic]}")
# Out:
# Topic 0: ['data', 'medical', 'information', 'provide', 'could', 'would', 'security', 'appreciate', 'support', 'please']
# Topic 1: ['data', 'security', 'software', 'issue', 'due', 'medical', 'system', 'access', 'breach', 'systems']
# Topic 2: ['issue', 'project', 'issues', 'problem', 'might', 'software', 'recent', 'management', 'due', 'updates']
# Topic 3: ['digital', 'data', 'would', 'strategies', 'analytics', 'investment', 'marketing', 'support', 'tools', 'brand']
# Topic 4: ['integration', 'would', 'could', 'billing', 'project', 'support', 'provide', 'management', 'saas', 'information']

# %%
X_lda_features = df.drop(columns=['email_content_clean', 'queue', 'queue_label'])

X_lda_features_train, X_lda_features_test = train_test_split(X_lda_features, test_size=0.3, random_state=42)

# %%
print(f'Shape of X_lda_features_train: {X_lda_features_train.shape}')
# Out:
# Shape of X_lda_features_train: (9629, 5)

# %%
print(f'Shape of X_lda_features_test: {X_lda_features_test.shape}')
# Out:
# Shape of X_lda_features_test: (4128, 5)

# %% [markdown]
# # Split Dataset

# %%
X = df['email_content_clean']
y = df['queue_label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9629,) (9629,)
# (4128,) (4128,)

# %% [markdown]
# ## Check class distribution

# %%
# check class imbalance in y_train
y_train.value_counts()
# Out:
# queue_label
# 0    3360
# 1    2182
# 2    1656
# 3    1331
# 4    1100
# Name: count, dtype: int64

# %%
# check class imbalance in y_test
y_test.value_counts()
# Out:
# queue_label
# 0    1377
# 1     891
# 2     754
# 3     611
# 4     495
# Name: count, dtype: int64

# %% [markdown]
# # Text Embedding

# %% [markdown]
# ## OpenAI Embedding

# %%
import tiktoken
from dotenv import load_dotenv
import dotenv
import os
from openai import OpenAI

# %%
dotenv.load_dotenv('/content/drive/MyDrive/ML Project/customer_ticket/openai_api.env')
client = OpenAI(
    # API key
    api_key=os.environ.get("OPENAI_API_KEY")
)

# %%
embedding_model = "text-embedding-3-small"
embedding_encoding = "cl100k_base"  #  the encoding for text-embedding-3-small
max_tokens = 8000 # max input is 8191

def gpt_embedding(texts, batch_size=4, model=embedding_model, encoding=embedding_encoding, max_tokens_limit=max_tokens):
   # Load the tiktoken encoding for the model once
    encoding = tiktoken.get_encoding(encoding)
    all_embeddings = []

    # Process texts in batches with tqdm progress bar
    for i in tqdm(range(0, len(texts), batch_size), desc="Processing batches"):
        batch_texts = []
        # Process each text in the current batch
        for text in texts[i:i+batch_size]:
            # Clean the text by replacing newline characters with space
            text_clean = text.replace("\n", " ")
            token_ids = encoding.encode(text_clean)
            # Truncate the text if token count exceeds the limit
            if len(token_ids) > max_tokens_limit:
                token_ids = token_ids[:max_tokens_limit]
                text_clean = encoding.decode(token_ids)
            batch_texts.append(text_clean)

         # Call the OpenAI API with the batch of texts
        response = client.embeddings.create(input=batch_texts, model=model)
        # Extract embeddings
        batch_embeddings = [result.embedding for result in response.data]
        all_embeddings.extend(batch_embeddings)

    return all_embeddings

# %%
# %time gpt_X_train = gpt_embedding(X_train)
# %time gpt_X_test = gpt_embedding(X_test)
# Out:
# Processing batches: 100%|██████████| 2408/2408 [28:25<00:00,  1.41it/s]
# CPU times: user 12 s, sys: 1.18 s, total: 13.2 s
# Wall time: 28min 25s
# Processing batches: 100%|██████████| 1032/1032 [12:20<00:00,  1.39it/s]
# CPU times: user 5.09 s, sys: 428 ms, total: 5.52 s
# Wall time: 12min 20s

# %%
joblib.dump(gpt_X_train, '/content/drive/MyDrive/ML Project/customer_ticket/embedding/gpt_X_train.pkl')
joblib.dump(gpt_X_test, '/content/drive/MyDrive/ML Project/customer_ticket/embedding/gpt_X_test.pkl')
# Out:
# ['/content/drive/MyDrive/ML Project/customer_ticket/embedding/gpt_X_test.pkl']

# %%
gpt_X_train = np.array(gpt_X_train)
gpt_X_test = np.array(gpt_X_test)

# %%
gpt_X_train.shape
# Out:
# (9629, 1536)

# %%
gpt_X_test.shape
# Out:
# (4128, 1536)

# %%
gpt_X_train = joblib.load('/content/drive/MyDrive/ML Project/customer_ticket/embedding/gpt_X_train.pkl')
gpt_X_test = joblib.load('/content/drive/MyDrive/ML Project/customer_ticket/embedding/gpt_X_test.pkl')

# %% [markdown]
# # Combining embedding and LDA features
# Now, we combine embeddings with LDA features (topics)

# %%
# Combine embedding and lda_features
# there is a mismatch in dimensions between embeddings and LDA features. embedding is a sparse matrix, while LDA features is a dense NumPy array.
# We convert the dense LDA features into a sparse matrix before combining them.
# using hstack, and csr_matrix for conversion

from scipy.sparse import hstack, csr_matrix

# convert the dense LDA features to a sparse matrix
X_lda_features_train_sparse = csr_matrix(X_lda_features_train.values)
X_lda_features_test_sparse = csr_matrix(X_lda_features_test.values)

combined_X_train = hstack((gpt_X_train, X_lda_features_train_sparse))
combined_X_test = hstack((gpt_X_test, X_lda_features_test_sparse))

# %%
# The combined matrices will now have the correct shape
print(f'Combined train shape: {combined_X_train.shape}')
print(f'Combined test shape: {combined_X_test.shape}')
# Out:
# Combined train shape: (9629, 1541)
# Combined test shape: (4128, 1541)

# %% [markdown]
# # Oversampling - SMOTE

# %% [markdown]
# We will apply SMOTE to solve class imbalance issues in classes, applying SMOTE to train set only
# ,

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
smote_targets = {
    1: 3000, # Product Support
    2: 3000, # Customer Service
    3: 3000, # IT Support
    4: 3000, # Billing and Payments
}

# Apply SMOTE only on training set
sm = SMOTE(sampling_strategy=smote_targets, random_state=42)

# apply SMOTE to all embeddings
combined_X_train_smote, y_train_smote = sm.fit_resample(combined_X_train, y_train)

# %% [markdown]
# # Classification

# %%
def evaluate_classifiers(model_name, X_train, X_test, y_train, y_test, embedding_name="Embedding"):

    models = {
        "LinearSVC": LinearSVC(random_state=42),
        "RandomForest": RandomForestClassifier(random_state=42),
        "GradientBoosting": GradientBoostingClassifier(random_state=42)
    }

    if model_name not in models:
        raise ValueError("Invalid model name. Choose from 'svm', 'random_forest', 'gradient_boosting'.")

    model = models[model_name]
    print(f"\n Running {model_name.replace('_', ' ').title()} on {embedding_name} Embeddings\n" + "-"*60)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    recall = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    report = classification_report(y_test, y_pred, zero_division=0)

    print(f"🔹 Accuracy     : {accuracy:.4f}")
    print(f"🔹 Precision    : {precision:.4f}")
    print(f"🔹 Recall       : {recall:.4f}")
    print(f"🔹 F1 Score     : {f1:.4f}")
    print("🔹 Classification Report:\n", report)

    return {
        "model": model_name,
        "embedding": embedding_name,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1,
        "report": report
    }

# %% [markdown]
# ## SVM

# %%
svm_results_openai = evaluate_classifiers("LinearSVC", combined_X_train_smote, combined_X_test, y_train_smote, y_test, "OpenAI")
# Out:
#  Running Linearsvc on OpenAI Embeddings
# ------------------------------------------------------------
# 🔹 Accuracy     : 0.4656
# 🔹 Precision    : 0.4735
# 🔹 Recall       : 0.4656
# 🔹 F1 Score     : 0.4662
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.45      0.49      1377
#            1       0.43      0.41      0.42       891
#            2       0.38      0.37      0.38       754
#            3       0.35      0.48      0.40       611
#            4       0.67      0.75      0.71       495
#
#     accuracy                           0.47      4128
#    macro avg       0.47      0.49      0.48      4128
# weighted avg       0.47      0.47      0.47      4128

# %% [markdown]
# ## RF

# %%
rf_results_openai = evaluate_classifiers("RandomForest", combined_X_train_smote, combined_X_test, y_train_smote, y_test, "OpenAI")
# Out:
#  Running Randomforest on OpenAI Embeddings
# ------------------------------------------------------------
# 🔹 Accuracy     : 0.6567
# 🔹 Precision    : 0.6733
# 🔹 Recall       : 0.6567
# 🔹 F1 Score     : 0.6536
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.81      0.70      1377
#            1       0.64      0.57      0.60       891
#            2       0.56      0.56      0.56       754
#            3       0.78      0.46      0.58       611
#            4       0.92      0.77      0.84       495
#
#     accuracy                           0.66      4128
#    macro avg       0.70      0.64      0.66      4128
# weighted avg       0.67      0.66      0.65      4128

# %% [markdown]
# ## Light GB

# %%
import lightgbm as lgb

# %%
# gb_results_openai = evaluate_classifiers("GradientBoosting", combined_X_train_smote, combined_X_test, y_train_smote, y_test, "OpenAI")

# %%
clf = lgb.LGBMClassifier()
clf.fit(combined_X_train_smote, y_train_smote)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.097060 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 392955
# [LightGBM] [Info] Number of data points in the train set: 15360, number of used features: 1541
# [LightGBM] [Info] Start training from score -1.519826
# [LightGBM] [Info] Start training from score -1.633154
# [LightGBM] [Info] Start training from score -1.633154
# [LightGBM] [Info] Start training from score -1.633154
# [LightGBM] [Info] Start training from score -1.633154
# LGBMClassifier()

# %%
y_pred = clf.predict(combined_X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.74      0.65      1377
#            1       0.56      0.55      0.56       891
#            2       0.56      0.51      0.54       754
#            3       0.67      0.46      0.55       611
#            4       0.92      0.75      0.83       495
#
#     accuracy                           0.62      4128
#    macro avg       0.66      0.60      0.62      4128
# weighted avg       0.63      0.62      0.62      4128

# %% [markdown]
# ## XGboost

# %% [markdown]
# # Hyperparameter tuning

# %% [markdown]
# ## Random Forest

# %%
parameters = [
    {"clf": [RandomForestClassifier(random_state=42)],
     "clf__n_estimators": [100, 200],
     "clf__criterion": ['gini', 'entropy'],
     "clf__max_depth": [10, 20, None],
     "clf__max_features": ['sqrt', 'log2'], # 'auto' is deprecated in scikit-learn 1.2 and removed in 1.4. Use 'sqrt' or 'log2'
     "clf__min_samples_split": [2, 5, 10],
     "clf__min_samples_leaf": [1, 5, 7]}
]

# %%
from sklearn.pipeline import Pipeline

# Create a pipeline with a dummy step for the classifier
pipeline = Pipeline([('clf', RandomForestClassifier(random_state=42))])

# create grid search
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)

grid = GridSearchCV(pipeline, parameters, cv=kfold, scoring='f1_weighted', verbose=2, n_jobs=-1)

# Fit the grid search to the data
grid.fit(combined_X_train_smote, y_train_smote)

# it took about 4h 30m for tuning
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('clf',
#                                         RandomForestClassifier(random_state=42))]),
#              n_jobs=-1,
#              param_grid=[{'clf': [RandomForestClassifier(random_state=42)],
#                           'clf__criterion': ['gini', 'entropy'],
#                           'clf__max_depth': [10, 20, None],
#                           'clf__max_features': ['sqrt', 'log2'],
#                           'clf__min_samples_leaf': [1, 5, 7],
#                           'clf__min_samples_split': [2, 5, 10],
#                           'clf__n_estimators': [100, 200]}],
#              scoring='f1_weighted', verbose=2)

# %%
# Print the best parameters and best score
print(f"Best parameters: {grid.best_params_}")
print(f"Best cross-validation F1-weighted score: {grid.best_score_:.4f}")
# Out:
# Best parameters: {'clf': RandomForestClassifier(random_state=42), 'clf__criterion': 'entropy', 'clf__max_depth': 20, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 1, 'clf__min_samples_split': 2, 'clf__n_estimators': 200}
# Best cross-validation F1-weighted score: 0.8435

# %%
# Evaluate the best model on the test set
best_rf_model = grid.best_estimator_
y_pred_rf_tuned = best_rf_model.predict(combined_X_test)

print("\nClassification Report for Tuned Random Forest on Test Set:\n")
print(classification_report(y_test, y_pred_rf_tuned, zero_division=0))
# Out:
# Classification Report for Tuned Random Forest on Test Set:
#
#               precision    recall  f1-score   support
#
#            0       0.61      0.82      0.70      1377
#            1       0.67      0.55      0.60       891
#            2       0.58      0.59      0.59       754
#            3       0.83      0.48      0.61       611
#            4       0.91      0.78      0.84       495
#
#     accuracy                           0.67      4128
#    macro avg       0.72      0.65      0.67      4128
# weighted avg       0.69      0.67      0.66      4128
